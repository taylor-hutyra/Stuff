# %%
from setup import *

mf = pd.read_csv('master_projects.csv')[['RESPONSE ID','NAME','FIRST NAME','LAST NAME']]
gf = pd.read_csv('gb_projects.csv')
gf = gf.iloc[:,[0,1]]
gf.columns = [['ID','NAME']]

merge_df = pd.merge(mf,gf, how = 'outer',indicator=True)
just_master = merge_df[merge_df['_merge']=='left_only']
just_guidebook = merge_df[merge_df['_merge']=='right_only']
both = merge_df[merge_df['_merge']=='both']

print(str(len(just_master))+' Projects ONLY in GoogleDoc Master')
# display(just_master.sort_values('NAME'))
print(str(len(just_guidebook))+' People ONLY in Guidebook')
# display(just_guidebook.sort_values('NAME'))
print(str(len(both))+' People with both a GoogleDoc Master project and Guidebook profile')
# display(both.sort_values('NAME'))

long_df = pd.concat([both,just_master])
display(long_df)
just_master.to_csv('to_master.csv')
just_guidebook.to_csv('just_guidebook.csv')
long_df.to_csv('merged_projects.csv')
# Out:
# 14 Projects ONLY in GoogleDoc Master
# 35 People ONLY in Guidebook
# 255 People with both a GoogleDoc Master project and Guidebook profile
#            RESPONSE ID                   NAME     FIRST NAME     LAST NAME  \
# 0    R_2tbMCkvrb5OpdWQ          Adebo, Philip         Philip         Adebo
# 1    R_21HvIc7qlSX11ZM     Adekanmbi, Abayomi        Abayomi     Adekanmbi
# 2    R_Tj6zY9EQl0RVzcl        Aderinto, Tunde          Tunde      Aderinto
# 3    R_1P7ZgvgYG5696sg      Aguirre, Isabella       Isabella       Aguirre
# 4    R_3dLzxzNjMPDBo3Z     Agwuegbo, Chiamaka       Chiamaka      Agwuegbo
# 5    R_2CTbgvmc4zd1jE0        Amaro, Mirelvia       Mirelvia         Amaro
# 6    R_3D0lo7gQevr6aPB    Amin Allen, Schirin        Schirin    Amin Allen
# 7    R_2pLVHP7JYn4kpzJ          Armah, Esther         Esther         Armah
# 8    R_3JgXb2y6z5myWXc     Arsekar, Shubharaj      Shubharaj       Arsekar
# 9    R_3kiUooKLLaCbChh          Ashraf, A H M          A H M        Ashraf
# 10   R_50kTh9yDKYI1PX3         Assis, Natalia        Natalia         Assis
# 11   R_2lvCGvGnWv15ZhT       Badmus, Olatunde       Olatunde        Badmus
# 12   R_1FKugNv4X226c4D        Baker, Jonathan       Jonathan         Baker
# 13   R_29tPTrsVJRd0WrY         Balzen, Hunter         Hunter        Balzen
# 15   R_2qws5afZMHIEYCb        Branch, Kathryn        Kathryn        Branch
# 16   R_1Ln6I4PLDl3mddQ        Baric, Veronika       Veronika         Baric
# 17   R_2Eg8c99l7je5DGR  Bassam, Seyed Siavash  Seyed Siavash        Bassam
# 18   R_2V3g6b2AtJYS808        Baugh, Ashleigh       Ashleigh         Baugh
# 19   R_3MxJpGWU3a0r0Es       Bautista, Ramiro         Ramiro      Bautista
# 20   R_237E9KdVoxdj2jh        Bedekar, Himani         Himani       Bedekar
# 21   R_2y9g4o3BFFKloEW          Bedwell, Cody           Cody       Bedwell
# 22   R_u9Wn1htxWOGtbDX            Bell, Duane          Duane          Bell
# 23   R_UgUJMv1EVu8aCNH      Belleny, Danielle       Danielle       Belleny
# 24   R_1LHBqoBotwOK2Wm     Benslimane, Nacera         Nacera    Benslimane
# 25   R_1LdK54eb9MasGC0      Bernet, Frederick      Frederick        Bernet
# 26   R_Z8CZ98s88RNc2WJ  Bernier-Vega, Agustin        Agustin  Bernier-Vega
# 27   R_1FScxFq5qfX5pYX         Brooks, Thomas         Thomas        Brooks
# 28   R_3LX8SW8mxj4OYEY           Brown, Tracy          Tracy         Brown
# 29   R_2YDNK7KHevvhgw5       Bocanegra, Diego          Diego     Bocanegra
# 30   R_cYZ7ZYKDKyym0Sd     Bourgeois, Dontrey        Dontrey     Bourgeois
# ..                 ...                    ...            ...           ...
# 252  R_d3Z9P1bioEoxc6R           Tovar, Maria          Maria         Tovar
# 253  R_1FKVWTrGOsew0eo     Trigueros, Chelsey        Chelsey     Trigueros
# 255  R_2azPtAMlz9152MU             Tuck, Sara           Sara          Tuck
# 256  R_1PRX7GjClvimkop       Vasquez, Liliana        Liliana       Vasquez
# 257  R_3VITx7SxGQ5Cpq1         Newell, Violet         Violet        Newell
# 258  R_s4NG5GTzEZ8bx7j       Villarreal, Pete           Pete    Villarreal
# 259  R_2uIZInLZQW9weeW          Vincze, Haley          Haley        Vincze
# 260  R_1QMg77KJWZrm1zP         Walker, Hannah         Hannah        Walker
# 261  R_210PQqQpojF9AHi         Warford, Khira          Khira       Warford
# 262  R_1gckYcGVSVA2ux7   Whisenhunt, Samantha       Samantha    Whisenhunt
# 263  R_2wiVy8hHTFtaDji         Wilcox, Daniel         Daniel        Wilcox
# 264  R_b3nMFQCS1jPXkkR        Shaffer, Sharla         Sharla       Shaffer
# 265  R_26m6UiXHcCsj8WD       Wommack, Mikayla        Mikayla       Wommack
# 266  R_1FeSKtG5EfWqgeZ          Wright, Avery          Avery        Wright
# 267  R_12GDN26yxUkwBqt            Sun, Xueqiu         Xueqiu           Sun
# 268  R_3EoGkrACFBzjJfw          Zubair, Fahim          Fahim        Zubair
# 14   R_0jjn7B0rtDD79S1       Bamgbose, Samuel         Samuel      Bamgbose
# 32   R_1dt6r9P5aYbQcZf    Castellanos, Roxana         Roxana   Castellanos
# 33   R_3FWjoFULiEer7d9    Castro, Jessa Rubie    Jessa Rubie        Castro
# 69   R_OONmMuTxMksQZGh   Ebhote, Oseze Andres   Oseze Andres        Ebhote
# 89   R_1jV9oNnBUT88oqi     Gonzales, Jannelle       Jannelle      Gonzales
# 97   R_1jUqFwzdkkBc41C     Gutierrez, Melissa        Melissa     Gutierrez
# 107  R_2z8ZBojCJYh9MJ4        herzberger, Leo            Leo    herzberger
# 111  R_3NUKPoeqgj36WGQ       Howard, Arndreya       Arndreya        Howard
# 112  R_z1N3N5pqn24ibwR           Howard, Drew           Drew        Howard
# 114  R_yVAtkgNu3B9ds2t      Gonzalez, Mariana        Mariana      Gonzalez
# 167  R_1pKwOZvPuBJolUg      Morris, Madeleine      Madeleine        Morris
# 178  R_1mWw6kCfGXdN1aJ        Neuweiler, Emma           Emma     Neuweiler
# 245  R_2YJQ5wjXFH7CR00          Thomas, Ermon          Ermon        Thomas
# 254  R_9nwYBZmXorKUCD7          Trimble, Will           Will       Trimble
#
#              ID     _merge
# 0   8786663.000       both
# 1   8786584.000       both
# 2   8786686.000       both
# 3   8786700.000       both
# 4   8786685.000       both
# 5   8786773.000       both
# 6   8786802.000       both
# 7   8786667.000       both
# 8   8786676.000       both
# 9   8786798.000       both
# 10  8786653.000       both
# 11  8786585.000       both
# 12  8786596.000       both
# 13  8786682.000       both
# 15  8786766.000       both
# 16  8786654.000       both
# 17  8786699.000       both
# 18  8786607.000       both
# 19  8786622.000       both
# 20  8786683.000       both
# 21  8786672.000       both
# 22  8786669.000       both
# 23  8786705.000       both
# 24  8786819.000       both
# 25  8786842.000       both
# 26  8786689.000       both
# 27  8786764.000       both
# 28  8786726.000       both
# 29  8786791.000       both
# 30  8786670.000       both
# ..          ...        ...
# 252 8786832.000       both
# 253 8786807.000       both
# 255 8786854.000       both
# 256 8786826.000       both
# 257 8786728.000       both
# 258 8786869.000       both
# 259 8786595.000       both
# 260 8786590.000       both
# 261 8786817.000       both
# 262 8786821.000       both
# 263 8786707.000       both
# 264 8786727.000       both
# 265 8786597.000       both
# 266 8786657.000       both
# 267 8786772.000       both
# 268 8786789.000       both
# 14          nan  left_only
# 32          nan  left_only
# 33          nan  left_only
# 69          nan  left_only
# 89          nan  left_only
# 97          nan  left_only
# 107         nan  left_only
# 111         nan  left_only
# 112         nan  left_only
# 114         nan  left_only
# 167         nan  left_only
# 178         nan  left_only
# 245         nan  left_only
# 254         nan  left_only
#
# [269 rows x 6 columns]
